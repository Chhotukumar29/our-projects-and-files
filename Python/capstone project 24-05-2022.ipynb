# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/chhot/PycharmProjects/PythonProjects/intellipaat trainer notes/WEEKDAYS BATCH/Capstone-project-2/Dataset/customer_churn.csv")

# %%
data.head(20)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
print(data)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
custmor_5 = data["Dependents"]

# %%
custmor_5
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042     No
# Name: Dependents, Length: 7043, dtype: object

# %%
custmor5 = data.iloc[:,4]

# %%
custmor5
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042     No
# Name: Dependents, Length: 7043, dtype: object

# %%
custmor_15 = data.iloc[:,14]

# %%
custmor_15
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: StreamingMovies, Length: 7043, dtype: object

# %%
data.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
senior_male_electronic = data[(data['gender'] == "Male")& (data['SeniorCitizen']==1) & (data['PaymentMethod']=='Electronic check')]

# %%
print(senior_male_electronic)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# ...          ...    ...            ...     ...        ...     ...
# 6837  6229-LSCKB   Male              1      No         No       6
# 6894  1400-MMYXY   Male              1     Yes         No       3
# 6914  7142-HVGBG   Male              1     Yes         No      43
# 6967  8739-WWKDU   Male              1      No         No      25
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
custmor_total_tenure = data[data["tenure"]>70 |(data["MonthlyCharges"]>100)]

# %%
custmor_total_tenure.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
# 5               Yes     Fiber optic             No  ...              Yes
#
# ...

# %%
two_mail_yes = data[(data['Contract']=="Two year") & (data['PaymentMethod']=="Mailed check") & (data["Churn"]=="Yes")]

# %%
two_mail_yes.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
custmor_333 = data.sample(333)

# %%
custmor_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3715  5288-AHOUP    Male              1      No         No      11
# 5038  4815-TUMEQ  Female              0      No         No      10
# 270   4385-GZQXV  Female              1      No         No      16
# 4046  0440-QEXBZ  Female              0      No         No      44
# 6619  2791-SFVEW  Female              0      No         No       9
# ...          ...     ...            ...     ...        ...     ...
# 1285  9134-CEQMF    Male              1     Yes         No       7
# 2852  5485-ITNPC    Male              0     Yes         No      66
# 2688  1569-TTNYJ    Male              0     Yes         No       5
# 5273  7673-BQGKU  Female              0     Yes        Yes      69
# 5650  6047-SUHPR    Male              0     Yes        Yes      39
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 3715          Yes            No     Fiber optic                   No  ...
# ...

# %%
data['Churn'].value_counts() # 1st method
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
data.groupby('Churn').size() # 2nd method
# Out:
# Churn
# No     5174
# Yes    1869
# dtype: int64

# %%
G = sns.barplot(x=data["InternetService"].unique().tolist(), y= data('InternetService').value_counts().tolist(), color = "red")
# plt.xlabel('Categories of Internet')
# plt.ylabel('Count of Categories')
# plt.title('Distribution of Internet Service') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-dda64b4103a2> in <module>
# ----> 1 G = sns.barplot(x=data["InternetService"].unique().tolist(), y= data('InternetService').value_counts().tolist(), color = "red")
#       2 # plt.xlabel('Categories of Internet')
#       3 # plt.ylabel('Count of Categories')
#       4 # plt.title('Distribution of Internet Service')
#       5 plt.show()
#
# TypeError: 'DataFrame' object is not callable

# %%
sns.barplot(data=["InternetService"].value_counts().keys().tolist(),data=["InternetService"].value_counts().tolist(),color="orange")
# Out:
#   File "<ipython-input-23-416d2ecf7994>", line 1
#     sns.barplot(data=["InternetService"].value_counts().keys().tolist(),data=["InternetService"].value_counts().tolist(),color="orange")
#                                                                         ^
# SyntaxError: keyword argument repeated

# %%
plt.hist(data['tenure'], bins= 30, color= 'g')
plt.title('Distribution of tenure')
plt.show()

# %%
sns.scatterplot(y=data['MonthlyCharges'] , x=data["tenure"], color = 'brown')
plt.xlabel('Tenure of customer')
plt.ylabel('Monthly Charges of customer')
plt.title('Tenure vs Monthly Charges')
# Out:
# Text(0.5, 1.0, 'Tenure vs Monthly Charges')

# %%
sns.boxplot(x=data['Contract'], y=data['tenure'])
plt.show()

# %%
from sklearn import linear_model 
from sklearn.model_selection import train_test_split

# %%
x = pd.DataFrame(data['tenure'])
y = pd.DataFrame(data['MonthlyCharges'])

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_pred,y_test)

# %%
rmse = np.sqrt(mse)
rmse()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-be499d842097> in <module>
#       1 rmse = np.sqrt(mse)
# ----> 2 rmse()
#
# TypeError: 'numpy.float64' object is not callable

# %%
x = pd.DataFrame(data['MonthlyCharges'])
y = pd.DataFrame(data['Churn'])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.35,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(x_train,y_train)
# Out:
# C:\Users\chhot\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %%
y_pred = logmodel.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
confusion_matrix(y_pred,y_test)
# Out:
# array([[1815,  651],
#        [   0,    0]], dtype=int64)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7360097323600974

# %%
(1815+0)/(1815+0+651+0)
# Out:
# 0.7360097323600974
