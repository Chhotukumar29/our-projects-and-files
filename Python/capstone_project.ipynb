# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
c=pd.read_csv("customer_churn.csv")

# %%
print(c)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
customer_5=c.iloc[:,4]

# %%
print(customer_5)
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042     No
# Name: Dependents, Length: 7043, dtype: object

# %%
#2.Extract the 15th column & store it in ‘customer_15’
customer_15=c.iloc[:,14]

# %%
print(customer_15)
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: StreamingMovies, Length: 7043, dtype: object

# %%
#3.
senior_male_e=c[(c["gender"]=="Male")&(c["SeniorCitizen"]==1)&(c["PaymentMethod"]=="Electronic check")]

# %%
senior_male_e.head()
# Out:
#     customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20  8779-QRDMV   Male              1      No         No       1           No
# 55  1658-BYGOY   Male              1      No         No      18          Yes
# 57  5067-XJQFU   Male              1     Yes        Yes      66          Yes
# 78  0191-ZHSKZ   Male              1      No         No      30          Yes
# 91  2424-WVHPL   Male              1      No         No       1          Yes
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 20  No phone service             DSL             No  ...              Yes
# 55               Yes     Fiber optic             No  ...               No
# 57               Yes     Fiber optic             No  ...              Yes
# 78                No             DSL            Yes  ...               No
# 91                No     Fiber optic             No  ...               No
#
# ...

# %%
#Extract all those customers whose tenure is greater than 70 months or their 
#Monthly charges is more than 100$ & store the result in ‘customer_total_tenure’
customer_tenure=c[(c["tenure"]>70)|(c["MonthlyCharges"]>100)]

# %%
customer_tenure.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 8            Yes     Fiber optic             No  ...              Yes
# 12           Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
# 14            No     Fiber optic            Yes  ...              Yes
# 15           Yes     Fiber optic            Yes  ...              Yes
#
# ...

# %%
#Extract all the customers whose Contract is of two years, payment method is Mailed 
#check & the value of Churn is ‘Yes’ & store the result in ‘two_mail_yes’
a=c[(c["Contract"]=="Two year")&(c["PaymentMethod"]=="Mailed check")&(c["Churn"]=="Yes")]

# %%
a.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
customer_333=c.sample(333)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3048  1728-BQDMA  Female              0      No         No       2
# 1388  9089-UOWJG  Female              0     Yes        Yes      12
# 3126  9754-CLVZW  Female              0     Yes        Yes      26
# 3802  7698-YFGEZ    Male              0      No         No       1
# 5287  9708-KFDBY    Male              0      No         No       1
# ...          ...     ...            ...     ...        ...     ...
# 567   5781-RFZRP    Male              0     Yes         No      71
# 263   7605-BDWDC  Female              0      No         No      31
# 1106  4159-NAAIX  Female              0      No         No      63
# 2633  4837-QUSFT  Female              0     Yes         No      65
# 869   0323-XWWTN    Male              0      No        Yes       3
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3048          Yes                No             DSL                   No  ...
# ...

# %%
#
c["Churn"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
c.groupby("Churn").size()
# Out:
# Churn
# No     5174
# Yes    1869
# dtype: int64

# %%
sns.barplot(c["InternetService"].value_counts().keys().tolist(),c["InternetService"].value_counts().tolist(),color="orange")
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
#2.
plt.hist(c["tenure"],bins=30,color="green")
plt.title("Distribution of tenure")
# Out:
# Text(0.5, 1.0, 'Distribution of tenure')

# %%
sns.scatterplot(x=c["tenure"],y=c["MonthlyCharges"],color="brown")
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='MonthlyCharges'>

# %%
sns.boxplot(c["tenure"],y=c["Contract"])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tenure', ylabel='Contract'>
