# %%
import numpy as np
import pandas as pd
import os, shutil
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import warnings
warnings.filterwarnings("ignore")

# %%
flist = os.listdir(r'C:\Users\chhot\Dropbox\BlackCoffer\StopWords')

# %%
with open ('StopWord.txt', 'w') as outfile:
    for file in flist:
        with open (file) as infile:
            for line in infile:
                line = line.split(' | ')[0]+'\n'
                outfile.write(line)

# %%
dataframe = pd.read_table('StopWords.txt', header=None, skip_blank_lines=True, encoding='windows-1252', names=['SW'])
stopwords = dataframe['SW'].tolist()

# %%
dataframe = pd.read_excel("C:/Users/chhot/Dropbox/BlackCoffer/Output Data Structure.xlsx")

# %%
dataframe
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0               NaN             NaN             NaN                 NaN
# ...

# %%
def complex_word_count(word):
    word = word.lower()
    count = 0
    vowels = 'aeiou'
    if word[0] in vowels:
        count += 1
    for index in range(1,len(word)):
        if word[index] in vowels and word[index-1] not in vowels:
            count += 1
    if count == 0:
        count += 1
    return count

# %%
path1 = r'C:\Users\chhot\Dropbox\BlackCoffer\text files'
path2 = r'C:\Users\chhot\Dropbox\BlackCoffer\text file cleaned'

tfiles = os.listdir(path1)
wrdcnt = []
cwrdcnt = []
twac = []
for i in dataframe['URL_ID'].values:
    with open (r'{}\{}.{}'.format(path1,i,'txt'), encoding='utf-8') as infile, open(r'{}\{}.{}'.format(path2,i,'txt'),'w',encoding='utf-8') as outfile:
        text = word_tokenize(infile.read())
        wrdcnt.append(len(text))
        cwcnt = 0
        for wrd in text:
            if complex_word_count(wrd)>2:
                cwcnt += 1
        cwrdcnt.append(cwcnt)
        print(cwrdcnt)
        filetext = [txt for txt in text if not txt in stopwords]
        outfile.write(' '.join(filetext))
        twac.append(len(filetext))

dataframe['wrdcnt'] = wrdcnt
dataframe['COMPLEX WORD COUNT'] = cwrdcnt
dataframe['twac'] = twac
# Out:
# [487]
# [487, 239]
# [487, 239, 443]
# [487, 239, 443, 257]
# [487, 239, 443, 257, 336]
# [487, 239, 443, 257, 336, 226]
# [487, 239, 443, 257, 336, 226, 162]
# [487, 239, 443, 257, 336, 226, 162, 1]
# [487, 239, 443, 257, 336, 226, 162, 1, 122]
# [487, 239, 443, 257, 336, 226, 162, 1, 122, 434]
# [487, 239, 443, 257, 336, 226, 162, 1, 122, 434, 383]
# [487, 239, 443, 257, 336, 226, 162, 1, 122, 434, 383, 307]
# [487, 239, 443, 257, 336, 226, 162, 1, 122, 434, 383, 307, 246]
# [487, 239, 443, 257, 336, 226, 162, 1, 122, 434, 383, 307, 246, 306]
# [487, 239, 443, 257, 336, 226, 162, 1, 122, 434, 383, 307, 246, 306, 317]
# [487, 239, 443, 257, 336, 226, 162, 1, 122, 434, 383, 307, 246, 306, 317, 144]
# [487, 239, 443, 257, 336, 226, 162, 1, 122, 434, 383, 307, 246, 306, 317, 144, 305]
# [487, 239, 443, 257, 336, 226, 162, 1, 122, 434, 383, 307, 246, 306, 317, 144, 305, 175]
# [487, 239, 443, 257, 336, 226, 162, 1, 122, 434, 383, 307, 246, 306, 317, 144, 305, 175, 187]
# ...

# %%
path3 = r'C:\Users\chhot\Dropbox\BlackCoffer\MasterDictionary'
path4 = r'C:\Users\chhot\Dropbox\BlackCoffer\MasterDictionaryCleaned'

kfiles = os.listdir(path3)
for kfile in kfiles:
    with open(r'{}\{}'.format(path3,kfile), encoding='windows-1252') as infile, open(r'{}\{}'.format(path4,kfile), 'w', encoding='windows-1252') as outfile:
        text1 = word_tokenize(infile.read())
        filetext1 = [txt for txt in text1 if not txt in stopwords]
        outfile.write(' '.join(filetext1))

# %%
with open(r'{}\{}'.format(path4,'positive-words.txt'), encoding='windows-1252') as file:
    PositiveWords = word_tokenize(file.read())

with open(r'{}\{}'.format(path4,'negative-words.txt'), encoding='windows-1252') as file:
    NegativeWords = word_tokenize(file.read())

# %%
positive_score = []
for i in dataframe['URL_ID'].values:
    pscore = 0
    with open(r'{}\{}.{}'.format(path2,i,'txt'),encoding='utf-8')as f:
        for txt in word_tokenize(f.read()):
            for txt1 in PositiveWords:
                if txt == txt1: pscore+=1
    positive_score.append(pscore)
dataframe["POSITIVE SCORE"] = positive_score

# %%
negative_score = []
for i in dataframe['URL_ID'].values:
    nscore = 0
    with open(r'{}\{}.{}'.format(path2,i,'txt'), encoding='utf-8') as f:
        for txt in word_tokenize(f.read()):
            for txt1 in NegativeWords:
                if txt == txt1: nscore-=1
    negative_score.append(-nscore)
dataframe['NEGATIVE SCORE'] = negative_score

# %%
dataframe['POLARITY SCORE']= (dataframe['POSITIVE SCORE']-dataframe['NEGATIVE SCORE'])/((dataframe['POSITIVE SCORE']+dataframe['NEGATIVE SCORE'])+ 0.000001)

# %%
dataframe['SUBJECTIVITY SCORE'] = (dataframe['POSITIVE SCORE']+dataframe['NEGATIVE SCORE'])/((dataframe['twac'])+ 0.000001)

# %%
sntcnt = []
for i in dataframe['URL_ID'].values:
    with open(r'{}\{}.{}'.format(path1,i,'txt'),encoding='utf-8')as infile:
        sent = sent_tokenize(infile.read())
        sntcnt.append(len(sent))

dataframe['sntcnt'] = sntcnt
dataframe['AVG sntcnt LENGTH'] = dataframe['wrdcnt']/dataframe['sntcnt']
dataframe['PERCENTAGE OF COMPLEX WORDS'] = dataframe['COMPLEX WORD COUNT']/dataframe['wrdcnt']
dataframe['FOG INDEX'] = 0.4*(dataframe['AVG SENTENCE LENGTH']+dataframe['PERCENTAGE OF COMPLEX WORDS'])

# %%
dataframe['AVG NUMBER OF WORDS PER SENTENCE']=round(dataframe['wrdcnt']/dataframe['sntcnt'],2)

# %%
def syllable_count(word):
    word = word.lower()
    count = 0
    vowels = "aeiou"
    if word[0] in vowels:
        count += 1
    for index in range(1, len(word)):
        if word[index] in vowels and word[index-1] not in vowels:
            count += 1
    if word.endswith(('es','ed')):
        count -= 1
    if count == 0:
        count += 1
    return count

# %%
scl = []
for i in dataframe['URL_ID'].values:
    with open(r'{}\{}.{}'.format(path1,i,'txt'),encoding='utf-8') as f:
        words = word_tokenize(f.read())
        sc = 0
        for word in words:
            sc += syllable_count(word)
    scl.append(sc)
    print(scl)
# Out:
# [2695]
# [2695, 1589]
# [2695, 1589, 2414]
# [2695, 1589, 2414, 1770]
# [2695, 1589, 2414, 1770, 2149]
# [2695, 1589, 2414, 1770, 2149, 1469]
# [2695, 1589, 2414, 1770, 2149, 1469, 930]
# [2695, 1589, 2414, 1770, 2149, 1469, 930, 9]
# [2695, 1589, 2414, 1770, 2149, 1469, 930, 9, 810]
# [2695, 1589, 2414, 1770, 2149, 1469, 930, 9, 810, 2578]
# [2695, 1589, 2414, 1770, 2149, 1469, 930, 9, 810, 2578, 2509]
# [2695, 1589, 2414, 1770, 2149, 1469, 930, 9, 810, 2578, 2509, 1651]
# [2695, 1589, 2414, 1770, 2149, 1469, 930, 9, 810, 2578, 2509, 1651, 1584]
# [2695, 1589, 2414, 1770, 2149, 1469, 930, 9, 810, 2578, 2509, 1651, 1584, 1740]
# [2695, 1589, 2414, 1770, 2149, 1469, 930, 9, 810, 2578, 2509, 1651, 1584, 1740, 1944]
# [2695, 1589, 2414, 1770, 2149, 1469, 930, 9, 810, 2578, 2509, 1651, 1584, 1740, 1944, 755]
# [2695, 1589, 2414, 1770, 2149, 1469, 930, 9, 810, 2578, 2509, 1651, 1584, 1740, 1944, 755, 1716]
# ...

# %%
NLTK_StopWords = list(set(stopwords.words("english")))

tfiles = os.listdir(path1)
WrdCnt = []
for i in dataframe['URL_ID'].values:
    with open(r'{}\{}.{}'.format(path1,i,'txt'),encoding='utf-8') as f:
        text2 = word_tokenize(f.read())
        filtext2 = [txt for txt in text2 if not txt in NLTK_StopWords and txt not in ['?','!',',','.']]
        WrdCnt.append(len(filtext2))

dataframe['WORD COUNT'] = WrdCnt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 NLTK_StopWords = list(set(stopwords.words("english")))
#       3 tfiles = os.listdir(path1)
#       4 WrdCnt = []
#
# AttributeError: 'list' object has no attribute 'words'

# %%
dataframe.drop(columns=['twac','wrdcnt','sntcnt'], inplace=True)

# %%
dataframe
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0                63              33        0.312500            0.076555
# ...
